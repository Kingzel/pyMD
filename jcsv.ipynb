# %%
import json
import csv
import pandas as pd
from sklearn .cluster import KMeans
import matplotlib.pyplot as plt
from sklearn import metrics, preprocessing 
from collections import defaultdict
from sklearn import preprocessing

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# df = pd.read_csv("data\\release_train_patients\\release_train_patients.csv")

# %%
conds = pd.read_json("data\\release_conditions.json")
evids = pd.read_json("data\\release_evidences.json")
train_patients = pd.read_csv("data\\release_train_patients\\release_train_patients.csv")

# %%
evids =evids.T
conds = conds.T
conds.drop(['cond-name-fr', 'cond-name-eng'], axis=1, inplace=True)
evids.drop(['question_fr', 'question_en','code_question'], axis=1, inplace=True)
# print(train_patients.head())
x = train_patients.drop(['PATHOLOGY','DIFFERENTIAL_DIAGNOSIS'],axis=1,inplace=False)
x  = train_patients['SEX']
x = pd.get_dummies(x, drop_first=True)
print(x.columns)
y = train_patients['PATHOLOGY']
# print(x.head(),y.head(),sep='\n\n\n')
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.30)
clf = RandomForestClassifier(n_estimators = 2)  
clf.fit(X_train, y_train) 
y_pred = clf.predict(X_test) 
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))

# %% [markdown]
# print(conds)<br>
# print(evids.shape)<br>
# print(evids.columns)<br>
# print(conds.columns)<br>
# print(evids.loc[evids['data_type'] == 'M'],len(evids.loc[evids['data_type'] == 'M']))<br>
# print(evids.loc[evids['data_type'] == 'C'],len(evids.loc[evids['data_type'] == 'C']))

# %% [markdown]
# for key in df2:<br>
#     print(key,df2[key],sep="------")

# %%
    # print(df.columns)
# d = defaultdict(preprocessing.LabelEncoder)
# fit = df.apply(lambda x: d[x.name].fit_transform(df))
# df['PATHOLOGY'] =label_encoder.fit_transform(df['PATHOLOGY']) 
# print(df['PATHOLOGY'].value_counts())
# print(df[:1].value_counts())
# print(df[['AGE','SEX','PATHOLOGY','EVIDENCES']].head())

# %% [markdown]
# with open('data\\release_evidences.json') as f:<br>
#     dat = json.load(f)

# %% [markdown]
# # print(dat['E_91'])

# %%
        
# # df = open('data\\release_evidences.csv','w+')
# # csvwriter = csv.writer(df)
# x = pd.DataFrame(columns =dat['E_91'].keys() )
# print(x)   
# # c = 0
# # for key in dat:
# #     if c==0:
# #         headers = []
# #         for attrib in dat[key]:
# #             headers.append(attrib)
# #         c+=1
# #         csvwriter.writerow(headers)
# #     else:
# #         csvwriter.writerow(dat[key].values())
